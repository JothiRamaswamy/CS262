# %%
import os
os.chdir('/Users/jothiramaswamy/Documents/Spring2023/CS262/Logical Clocks/clock_variation')

# %%
import csv
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
df_0 = pd.read_csv('experiment1_10/csvs/log_0_7.csv')
times_0 = df_0["logical_clock_time"]
differences_0 = [times_0[0]] + [times_0[i] - times_0[i-1] for i in range(1, len(times_0))]
avg_0_10 = sum(differences_0)/len(differences_0)
df_1 = pd.read_csv('experiment1_10/csvs/log_1_1.csv')
times_1 = df_1["logical_clock_time"]
differences_1 = [times_1[0]] + [times_1[i] - times_1[i-1] for i in range(1, len(times_1))]
avg_1_10 = sum(differences_1)/len(differences_1)
df_2 = pd.read_csv('experiment1_10/csvs/log_2_3.csv')
times_2 = df_2["logical_clock_time"]
differences_2 = [times_2[0]] + [times_2[i] - times_2[i-1] for i in range(1, len(times_2))]
avg_2_10 = sum(differences_2)/len(differences_2)
avgs_10 = [[1, 10]] + sorted([avg_0_10, avg_1_10, avg_2_10])

plt.title("Event Type Distribution for Clock Tick Rate Range of [1,8]")
event_type_dict_0 = df_0.groupby("event_type").size().to_dict()
plt.xlabel("Machine with the fastest speed")
plt.bar(event_type_dict_0.keys(), event_type_dict_0.values())
# Out:
# <BarContainer object of 3 artists>

# %%
event_type_dict_1 = df_1.groupby("event_type").size().to_dict()
plt.xlabel("Machine with the lowest speed")
plt.bar(list(event_type_dict_1.keys()) + ["Send"], list(event_type_dict_1.values()) + [0])
# Out:
# <BarContainer object of 3 artists>

# %%
event_type_dict_2 = df_2.groupby("event_type").size().to_dict()
plt.xlabel("Machine with the middle speed")
plt.bar(event_type_dict_2.keys(), event_type_dict_2.values())
# Out:
# <BarContainer object of 3 artists>

# %%
df_0 = pd.read_csv('experiment1_8/csvs/log_0_1.csv')
times_0 = df_0["logical_clock_time"]
differences_0 = [times_0[0]] + [times_0[i] - times_0[i-1] for i in range(1, len(times_0))]
avg_0_8 = sum(differences_0)/len(differences_0)
df_1 = pd.read_csv('experiment1_8/csvs/log_1_7.csv')
times_1 = df_1["logical_clock_time"]
differences_1 = [times_1[0]] + [times_1[i] - times_1[i-1] for i in range(1, len(times_1))]
avg_1_8 = sum(differences_1)/len(differences_1)
df_2 = pd.read_csv('experiment1_8/csvs/log_2_8.csv')
times_2 = df_2["logical_clock_time"]
differences_2 = [times_2[0]] + [times_2[i] - times_2[i-1] for i in range(1, len(times_2))]
avg_2_8 = sum(differences_2)/len(differences_2)
avgs_8 = [[1, 8]] + sorted([avg_0_8, avg_1_8, avg_2_8])

fig, (ax_0, ax_1, ax_2) = plt.subplots(1,3)
plt.title("Event Type Distribution for Clock Tick Rate Range of [1,8]")
event_type_dict_0 = df_0.groupby("event_type").size().to_dict()
ax_0.bar(list(event_type_dict_0.keys()) + ["Send"], list(event_type_dict_0.values()) + [0])
event_type_dict_1 = df_1.groupby("event_type").size().to_dict()
ax_1.bar(event_type_dict_1.keys(), event_type_dict_1.values())
# Out:
# <BarContainer object of 3 artists>

# %%
event_type_dict_2 = df_2.groupby("event_type").size().to_dict()
plt.bar(event_type_dict_2.keys(), event_type_dict_2.values())
# Out:
# <BarContainer object of 3 artists>

# %%
df = pd.read_csv('experiment1_4/csvs/log_0_3.csv')
times_0 = df["logical_clock_time"]
differences_0 = [times_0[0]] + [times_0[i] - times_0[i-1] for i in range(1, len(times_0))]
avg_0_4 = sum(differences_0)/len(differences_0)
times_1 = pd.read_csv('experiment1_4/csvs/log_1_2.csv')["logical_clock_time"]
differences_1 = [times_1[0]] + [times_1[i] - times_1[i-1] for i in range(1, len(times_1))]
avg_1_4 = sum(differences_1)/len(differences_1)
times_2 = pd.read_csv('experiment1_4/csvs/log_2_3.csv')["logical_clock_time"]
differences_2 = [times_2[0]] + [times_2[i] - times_2[i-1] for i in range(1, len(times_2))]
avg_2_4 = sum(differences_2)/len(differences_2)
avgs_4 = [[1, 4]] + sorted([avg_0_4, avg_1_4, avg_2_4])

event_type_dict = df.groupby("event_type").size().to_dict()
plt.title("Event Type Distribution for Clock Tick Rate Range of [1,4]")
plt.bar(event_type_dict.keys(), event_type_dict.values())
# Out:
# <BarContainer object of 3 artists>

# %%
df = pd.read_csv('experiment1_1/csvs/log_0_1.csv')
times_0 = df["logical_clock_time"]
differences_0 = [times_0[0]] + [times_0[i] - times_0[i-1] for i in range(1, len(times_0))]
avg_0_1 = sum(differences_0)/len(differences_0)
times_1 = pd.read_csv('experiment1_1/csvs/log_1_1.csv')["logical_clock_time"]
differences_1 = [times_1[0]] + [times_1[i] - times_1[i-1] for i in range(1, len(times_1))]
avg_1_1 = sum(differences_1)/len(differences_1)
times_2 = pd.read_csv('experiment1_1/csvs/log_2_1.csv')["logical_clock_time"]
differences_2 = [times_2[0]] + [times_2[i] - times_2[i-1] for i in range(1, len(times_2))]
avg_2_1 = sum(differences_2)/len(differences_2)
avgs_1 = [[1, 1]] + sorted([avg_0_1, avg_1_1, avg_2_1])

event_type_dict = df.groupby("event_type").size().to_dict()
plt.title("Event Type Distribution for Clock Tick Rate Range of [1,1]")
plt.bar(event_type_dict.keys(), event_type_dict.values())
# Out:
# <BarContainer object of 3 artists>

# %%
header = ["Range of Clock Rate", "Machine 1", "Machine 2", "Machine 3"]
print("average logical clock jump size for machines with different ranges of clock rates")
df = pd.DataFrame([avgs_1, avgs_4, avgs_8, avgs_10], columns=header)
df.to_html()
# Out:
# average logical clock jump size for machines with different ranges of clock rates
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Range of Clock Rate</th>\n      <th>Machine 1</th>\n      <th>Machine 2</th>\n      <th>Machine 3</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>[1, 1]</td>\n      <td>1.0</td>\n      <td>1.000000</td>\n      <td>1.000000</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>[1, 4]</td>\n      <td>1.0</td>\n      <td>1.000000</td>\n      <td>1.478992</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>[1, 8]</td>\n      <td>1.0</td>\n      <td>1.915254</td>\n      <td>3.750000</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>[1, 10]</td>\n      <td>1.0</td>\n      <td>2.254237</td>\n      <td>4.216667</td>\n    </tr>\n  </tbody>\n</table>'
